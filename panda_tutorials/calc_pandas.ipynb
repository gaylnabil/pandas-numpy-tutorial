# %% [markdown]
# ### 1- Load Data with Pandas Package

# %%
import pandas as pd
data_frames = pd.read_csv('../data/uscities.csv')
# Show 50 rows of data
data_frames.head(50)
# Out:
#             ID            city      city_ascii state_id            state_name  \
# 0   1840034016        New York        New York       NY              New York
# 1   1840020491     Los Angeles     Los Angeles       CA            California
# 2   1840000494         Chicago         Chicago       IL              Illinois
# 3   1840015149           Miami           Miami       FL               Florida
# 4   1840019440          Dallas          Dallas       TX                 Texas
# 5   1840020925         Houston         Houston       TX                 Texas
# 6   1840000673    Philadelphia    Philadelphia       PA          Pennsylvania
# 7   1840013660         Atlanta         Atlanta       GA               Georgia
# 8   1840006060      Washington      Washington       DC  District of Columbia
# 9   1840000455          Boston          Boston       MA         Massachusetts
# 10  1840020568         Phoenix         Phoenix       AZ               Arizona
# ...

# %%
# Display the Dimension of the table
data_frames.shape
# Out:
# (30844, 17)

# %%
data_frames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30844 entries, 0 to 30843
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            30844 non-null  int64
#  1   city          30844 non-null  object
#  2   city_ascii    30844 non-null  object
#  3   state_id      30844 non-null  object
#  4   state_name    30844 non-null  object
#  5   county_fips   30844 non-null  int64
#  6   county_name   30844 non-null  object
#  7   lat           30844 non-null  float64
#  8   lng           30844 non-null  float64
#  9   population    30844 non-null  int64
#  10  density       30844 non-null  float64
#  11  source        30844 non-null  object
#  12  military      30844 non-null  bool
#  13  incorporated  30844 non-null  bool
#  14  timezone      30844 non-null  object
#  15  zips          30842 non-null  object
#  16  ranking       30844 non-null  int64
# dtypes: bool(2), float64(3), int64(4), object(8)
# ...

# %%
# Display specific number of columns
# pd.set_option('display.max_columns', 6)
pd.set_option('display.max_rows', 100)
data_frames_display = pd.read_csv('../data/cities.csv')
data_frames_display.head()
# Out:
#    Reference  LatD   LatM   LatS NS  LonD  LonM  LonS EW             City  \
# 0        320    41      5     59  N    80    39     0  W       Youngstown
# 1        321    42     52     48  N    97    23    23  W          Yankton
# 2        322    46     35     59  N   120    30    36  W           Yakima
# 3        323    42     16     12  N    71    48     0  W        Worcester
# 4        324    43     37     48  N    89    46    11  W  Wisconsin Dells
#
#   State
# 0    OH
# 1    SD
# 2    WA
# 3    MA
# 4    WI

# %% [markdown]
# ### 2- Using DataFrame and Series Basics

# %%
pd.reset_option('^display.', silent=True)
data_frames
# Out:
#                ID                     city               city_ascii state_id  \
# 0      1840034016                 New York                 New York       NY
# 1      1840020491              Los Angeles              Los Angeles       CA
# 2      1840000494                  Chicago                  Chicago       IL
# 3      1840015149                    Miami                    Miami       FL
# 4      1840019440                   Dallas                   Dallas       TX
# ...           ...                      ...                      ...      ...
# 30839  1840152922                Ironville                Ironville       PA
# 30840  1840024978                  Newkirk                  Newkirk       NM
# 30841  1840018314           Falcon Village           Falcon Village       TX
# 30842  1840153068             Hidden Lakes             Hidden Lakes       OH
# 30843  1840153158  El Monte Mobile Village  El Monte Mobile Village       CA
#
# ...

# %%
# Show table with max rows of 10 and 2 last columns
# iloc: Integer Location
# iloc[rows_indexes, cols_indexes]
data_frames.iloc[:10, :-2]
# Out:
#            ID          city    city_ascii state_id            state_name  \
# 0  1840034016      New York      New York       NY              New York
# 1  1840020491   Los Angeles   Los Angeles       CA            California
# 2  1840000494       Chicago       Chicago       IL              Illinois
# 3  1840015149         Miami         Miami       FL               Florida
# 4  1840019440        Dallas        Dallas       TX                 Texas
# 5  1840020925       Houston       Houston       TX                 Texas
# 6  1840000673  Philadelphia  Philadelphia       PA          Pennsylvania
# 7  1840013660       Atlanta       Atlanta       GA               Georgia
# 8  1840006060    Washington    Washington       DC  District of Columbia
# 9  1840000455        Boston        Boston       MA         Massachusetts
#
#    county_fips           county_name      lat       lng  population  density  \
# 0        36081                Queens  40.6943  -73.9249    18972871  10768.2
# ...

# %%
data_frames.columns
# Out:
# Index(['ID', 'city', 'city_ascii', 'state_id', 'state_name', 'county_fips',
#        'county_name', 'lat', 'lng', 'population', 'density', 'source',
#        'military', 'incorporated', 'timezone', 'zips', 'ranking'],
#       dtype='object')

# %%
# loc:Location
# loc[rows_indexes, cols_names]
data_frames.loc[:4, 'ID': 'state_name']
# Out:
#            ID         city   city_ascii state_id  state_name
# 0  1840034016     New York     New York       NY    New York
# 1  1840020491  Los Angeles  Los Angeles       CA  California
# 2  1840000494      Chicago      Chicago       IL    Illinois
# 3  1840015149        Miami        Miami       FL     Florida
# 4  1840019440       Dallas       Dallas       TX       Texas

# %%
data_frames['city'].value_counts()
# Out:
# Franklin                   29
# Fairview                   24
# Marion                     23
# Clinton                    23
# Greenville                 22
#                            ..
# Redington Shores            1
# Mount Holly Springs         1
# Sumrall                     1
# Camino                      1
# El Monte Mobile Village     1
# Name: city, Length: 20721, dtype: int64

# %% [markdown]
# ### 3- Indexes - How to Set, Reset, and Use Indexes

# %%
data_frames.set_index('ID', inplace=True)

# %%
data_frames.index
# Out:
# Int64Index([1840034016, 1840020491, 1840000494, 1840015149, 1840019440,
#             1840020925, 1840000673, 1840013660, 1840006060, 1840000455,
#             ...
#             1840152590, 1840152591, 1840075938, 1840039843, 1840022983,
#             1840152922, 1840024978, 1840018314, 1840153068, 1840153158],
#            dtype='int64', name='ID', length=30844)

# %%
# Indexing data with ID indexing
# loc: [ID indexing, column_names]
data_frames.loc[1840034016:1840015149, ['city', 'timezone']]
# Out:
#                    city             timezone
# ID
# 1840034016     New York     America/New_York
# 1840020491  Los Angeles  America/Los_Angeles
# 1840000494      Chicago      America/Chicago
# 1840015149        Miami     America/New_York

# %%
data_frames.sort_index(ascending=True)
# Out:
#                                               city  \
# ID
# 1630023526                              San Germán
# 1630023527                                 Luyando
# 1630023528                                  Aguada
# 1630023532                              Carrizales
# 1630023533                               Corcovado
# ...                                            ...
# 1840153160                              Cottonwood
# 1840153161                                 Fairfax
# 1840153162            El Centro Naval Air Facility
# 1840153163                   Eastern Goleta Valley
# 1840153164  University of California-Santa Barbara
#
#                                         city_ascii state_id   state_name  \
# ID
# 1630023526                              San German       PR  Puerto Rico
# 1630023527                                 Luyando       PR  Puerto Rico
# 1630023528                                  Aguada       PR  Puerto Rico
# ...

# %% [markdown]
# ### 4- Filtering - Using Conditionals to Filter Rows and Columns

# %%
filter_data = (data_frames['population'] >= 5668165)

# %%
data_frames.loc[filter_data, ['city', 'state_name', 'county_name', 'population', 'ranking']]
# Out:
#                    city  state_name  county_name  population  ranking
# ID
# 1840034016     New York    New York       Queens    18972871        1
# 1840020491  Los Angeles  California  Los Angeles    12121244        1
# 1840000494      Chicago    Illinois         Cook     8595181        1
# 1840015149        Miami     Florida   Miami-Dade     5711945        1
# 1840019440       Dallas       Texas       Dallas     5668165        1

# %%
cities = ['Worcester', 'San Francisco', 'Richmond']
filter_data = data_frames['city'].isin(cities) # Filter Data City if is the city is in 'City list'

# %%
data_frames.loc[filter_data, 'city': 'timezone']
# Out:
#                      city     city_ascii state_id     state_name  county_fips  \
# ID
# 1840021543  San Francisco  San Francisco       CA     California         6075
# 1840001698       Richmond       Richmond       VA       Virginia        51760
# 1840000434      Worcester      Worcester       MA  Massachusetts        25027
# 1840020277       Richmond       Richmond       CA     California         6013
# 1840014176       Richmond       Richmond       IN        Indiana        18177
# 1840014341       Richmond       Richmond       KY       Kentucky        21151
# 1840020947       Richmond       Richmond       TX          Texas        48157
# 1840009600       Richmond       Richmond       MO       Missouri        29177
# 1840003091       Richmond       Richmond       MI       Michigan        26099
# 1840020109       Richmond       Richmond       UT           Utah        49005
# 1840011138       Richmond       Richmond       IL       Illinois        17111
# ...

# %%
filter_data = data_frames['state_name'].str.contains('New', na=False) # Filter Data City if is the city is in 'City list'
data_frames.loc[filter_data, 'city': 'timezone']
# Out:
#                       city      city_ascii state_id  state_name  county_fips  \
# ID
# 1840034016        New York        New York       NY    New York        36081
# 1840034030        Brooklyn        Brooklyn       NY    New York        36047
# 1840034002          Queens          Queens       NY    New York        36081
# 1840034000       Manhattan       Manhattan       NY    New York        36061
# 1840033999           Bronx           Bronx       NY    New York        36005
# ...                    ...             ...      ...         ...          ...
# 1840150857        Old Town        Old Town       NM  New Mexico        35029
# 1840150858       Black Hat       Black Hat       NM  New Mexico        35031
# 1840025083        Garfield        Garfield       NM  New Mexico        35013
# 1840151823  Red Rock Ranch  Red Rock Ranch       NM  New Mexico        35031
# 1840024978         Newkirk         Newkirk       NM  New Mexico        35019
#
# ...

# %% [markdown]
# ### 5- Updating Rows and Columns - Modifying Data Within DataFrames

# %%
data_frames.columns
# Out:
# Index(['city', 'city_ascii', 'state_id', 'state_name', 'county_fips',
#        'county_name', 'lat', 'lng', 'population', 'density', 'source',
#        'military', 'incorporated', 'timezone', 'zips', 'ranking'],
#       dtype='object')

# %%
data_frames.columns = [col.replace('_', '/').upper() for col in data_frames.columns]
data_frames.columns
# Out:
# Index(['CITY', 'CITY/ASCII', 'STATE/ID', 'STATE/NAME', 'COUNTY/FIPS',
#        'COUNTY/NAME', 'LAT', 'LNG', 'POPULATION', 'DENSITY', 'SOURCE',
#        'MILITARY', 'INCORPORATED', 'TIMEZONE', 'ZIPS', 'RANKING'],
#       dtype='object')

# %%
data_frames.rename(columns={'CITY': 'City'}, inplace=True)
data_frames.columns
# Out:
# Index(['City', 'CITY/ASCII', 'STATE/ID', 'STATE/NAME', 'COUNTY/FIPS',
#        'COUNTY/NAME', 'LAT', 'LNG', 'POPULATION', 'DENSITY', 'SOURCE',
#        'MILITARY', 'INCORPORATED', 'TIMEZONE', 'ZIPS', 'RANKING'],
#       dtype='object')

# %%
# Rename and replace all columns
data_frames.columns = [name.replace('/', '_').lower() for name in data_frames.columns]
data_frames.columns
# Out:
# Index(['city', 'city_ascii', 'state_id', 'state_name', 'county_fips',
#        'county_name', 'lat', 'lng', 'population', 'density', 'source',
#        'military', 'incorporated', 'timezone', 'zips', 'ranking'],
#       dtype='object')

# %%
# Reset indexing
data_frames.reset_index(inplace=True)

# %%
# Edit a specific cell in the table
data_frames.loc[3, ['city', 'city_ascii', 'state_id']] = ['Manitoba', 'Manitoba', 'MB']
data_frames.loc[[1,2,3], ['city', 'city_ascii', 'state_id']]
# Out:
#           city   city_ascii state_id
# 1  Los Angeles  Los Angeles       CA
# 2      Chicago      Chicago       IL
# 3     Manitoba     Manitoba       MB

# %%
# Find and Edit element in the row
# Manhattan	Manhattan	NY
data_filter = (data_frames['city'] == 'Manitoba')
data_frames.loc[data_filter, ['city', 'city_ascii', 'state_id']] = ['Manhattan', 'Manhattan', 'NY']
data_frames.loc[:5, ['city', 'city_ascii', 'state_id']]
# Out:
#           city   city_ascii state_id
# 0     New York     New York       NY
# 1  Los Angeles  Los Angeles       CA
# 2      Chicago      Chicago       IL
# 3    Manhattan    Manhattan       NY
# 4       Dallas       Dallas       TX
# 5      Houston      Houston       TX

# %%
# Edit an element in all rows of the table
data_frames['city'] = data_frames['city'].str.upper()
data_frames.loc[:5, ['city', 'city_ascii', 'state_id']]
# Out:
#           city   city_ascii state_id
# 0     NEW YORK     New York       NY
# 1  LOS ANGELES  Los Angeles       CA
# 2      CHICAGO      Chicago       IL
# 3    MANHATTAN    Manhattan       NY
# 4       DALLAS       Dallas       TX
# 5      HOUSTON      Houston       TX

# %%
# Using apply function: .apply(function)
data_frames['city'].apply(len)
# Out:
# 0         8
# 1        11
# 2         7
# 3         9
# 4         6
#          ..
# 30839     9
# 30840     7
# 30841    14
# 30842    12
# 30843    23
# Name: city, Length: 30844, dtype: int64

# %%
data_frames['city'] = data_frames['city'].apply(lambda x: x.capitalize())
data_frames.loc[:5, ['city', 'city_ascii', 'state_id']]
# Out:
#           city   city_ascii state_id
# 0     New york     New York       NY
# 1  Los angeles  Los Angeles       CA
# 2      Chicago      Chicago       IL
# 3    Manhattan    Manhattan       NY
# 4       Dallas       Dallas       TX
# 5      Houston      Houston       TX

# %%
filter_data = (data_frames['incorporated'] == True)
data_frames.loc[filter_data, 'population']
# Out:
# 0        18972871
# 1        12121244
# 2         8595181
# 3         5711945
# 4         5668165
#            ...
# 30824           0
# 30826           0
# 30827           0
# 30836           0
# 30837           0
# Name: population, Length: 20219, dtype: int64

# %%
average = int(data_frames.loc[filter_data, 'population'].sum() / data_frames.loc[filter_data, 'population'].count())
print('average:', average)
# Out:
# average: 17956

# %% [markdown]
# ### 6- Add/Remove Rows and Columns From DataFrames

# %%
# Drop specific columns from the DataFrame
data_frames = data_frames.drop(columns={'zips', 'source', 'ranking'})
data_frames
# Out:
#                ID                     city               city_ascii state_id  \
# 0      1840034016                 New york                 New York       NY
# 1      1840020491              Los angeles              Los Angeles       CA
# 2      1840000494                  Chicago                  Chicago       IL
# 3      1840015149                Manhattan                Manhattan       NY
# 4      1840019440                   Dallas                   Dallas       TX
# ...           ...                      ...                      ...      ...
# 30839  1840152922                Ironville                Ironville       PA
# 30840  1840024978                  Newkirk                  Newkirk       NM
# 30841  1840018314           Falcon village           Falcon Village       TX
# 30842  1840153068             Hidden lakes             Hidden Lakes       OH
# 30843  1840153158  El monte mobile village  El Monte Mobile Village       CA
#
# ...

# %%
# Add a new Column 'full_state' with Concatenation of columns 'state_id' and 'state_name'
data_frames['full_state'] = data_frames['state_id'] + ' - ' + data_frames['state_name']
data_frames
# Out:
#                ID                     city               city_ascii state_id  \
# 0      1840034016                 New york                 New York       NY
# 1      1840020491              Los angeles              Los Angeles       CA
# 2      1840000494                  Chicago                  Chicago       IL
# 3      1840015149                Manhattan                Manhattan       NY
# 4      1840019440                   Dallas                   Dallas       TX
# ...           ...                      ...                      ...      ...
# 30839  1840152922                Ironville                Ironville       PA
# 30840  1840024978                  Newkirk                  Newkirk       NM
# 30841  1840018314           Falcon village           Falcon Village       TX
# 30842  1840153068             Hidden lakes             Hidden Lakes       OH
# 30843  1840153158  El monte mobile village  El Monte Mobile Village       CA
#
# ...

# %%
# Drop specific columns from the DataFrame
if data_frames.columns.isin(['state_id', 'state_name']).any():
    data_frames.drop(columns={'state_id', 'state_name'}, inplace=True)
data_frames
# Out:
#                ID                     city               city_ascii  \
# 0      1840034016                 New york                 New York
# 1      1840020491              Los angeles              Los Angeles
# 2      1840000494                  Chicago                  Chicago
# 3      1840015149                Manhattan                Manhattan
# 4      1840019440                   Dallas                   Dallas
# ...           ...                      ...                      ...
# 30839  1840152922                Ironville                Ironville
# 30840  1840024978                  Newkirk                  Newkirk
# 30841  1840018314           Falcon village           Falcon Village
# 30842  1840153068             Hidden lakes             Hidden Lakes
# 30843  1840153158  El monte mobile village  El Monte Mobile Village
#
#        county_fips  county_name      lat       lng  population  density  \
# 0            36081       Queens  40.6943  -73.9249    18972871  10768.2
# ...

# %%
# Split the column into multiple columns
data_frames['full_state'].str.split(' - ', expand = True)
# Out:
#         0             1
# 0      NY      New York
# 1      CA    California
# 2      IL      Illinois
# 3      NY       Florida
# 4      TX         Texas
# ...    ..           ...
# 30839  PA  Pennsylvania
# 30840  NM    New Mexico
# 30841  TX         Texas
# 30842  OH          Ohio
# 30843  CA    California
#
# [30844 rows x 2 columns]

# %%
# Add 2 Columns 'state_id', 'state_name' in DataFrame after splitting 'full_state' column
data_frames[['state_id', 'state_name']] = data_frames['full_state'].str.split(' - ', expand = True)
data_frames
# Out:
#                ID                     city               city_ascii  \
# 0      1840034016                 New york                 New York
# 1      1840020491              Los angeles              Los Angeles
# 2      1840000494                  Chicago                  Chicago
# 3      1840015149                Manhattan                Manhattan
# 4      1840019440                   Dallas                   Dallas
# ...           ...                      ...                      ...
# 30839  1840152922                Ironville                Ironville
# 30840  1840024978                  Newkirk                  Newkirk
# 30841  1840018314           Falcon village           Falcon Village
# 30842  1840153068             Hidden lakes             Hidden Lakes
# 30843  1840153158  El monte mobile village  El Monte Mobile Village
#
#        county_fips  county_name      lat       lng  population  density  \
# 0            36081       Queens  40.6943  -73.9249    18972871  10768.2
# ...

# %%
# Drop specified rows from DataFrame
filter_data = data_frames['city'] == 'Richmond'
indexes = data_frames[filter_data].index
indexes
# Out:
# Int64Index([49, 396, 1290, 1334, 3545, 5861, 5930, 9071, 10423, 13594, 19202,
#             19790, 20083],
#            dtype='int64')

# %%
data_frames.drop(index = indexes)
# Out:
#                ID                     city               city_ascii  \
# 0      1840034016                 New york                 New York
# 1      1840020491              Los angeles              Los Angeles
# 2      1840000494                  Chicago                  Chicago
# 3      1840015149                Manhattan                Manhattan
# 4      1840019440                   Dallas                   Dallas
# ...           ...                      ...                      ...
# 30839  1840152922                Ironville                Ironville
# 30840  1840024978                  Newkirk                  Newkirk
# 30841  1840018314           Falcon village           Falcon Village
# 30842  1840153068             Hidden lakes             Hidden Lakes
# 30843  1840153158  El monte mobile village  El Monte Mobile Village
#
#        county_fips  county_name      lat       lng  population  density  \
# 0            36081       Queens  40.6943  -73.9249    18972871  10768.2
# ...

# %% [markdown]
# ### 7- Sorting DataFrames

# %%
# Sorting with multiple columns
# inplace=True: means making the change to DataFrame
data_frames.sort_values(by =['county_name', 'population'], ascending = True, inplace=True)

data_frames[['ID',, 'county_name', 'state_name', 'population']].head(40)
# Out:
#   Cell In[458], line 5
#     data_frames[['ID',, 'county_name', 'state_name', 'population']].head(40)
#                       ^
# SyntaxError: invalid syntax

# %%
# Sorting with multiple  with multiple ascending
# Sort By['state_name', 'population'] ascending with 'state_name' and descending with 'population'
data_frames.sort_values(by =['county_name', 'population'], ascending = [True, False], inplace=True)

data_frames[['ID', 'county_name', 'state_name', 'population']].head(40)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9124\1447606483.py in ?()
#       1 # Sorting with multiple  with multiple ascending
#       2 # Sort By['state_name', 'population'] ascending with 'state_name' and descending with 'population'
# ----> 3 data_frames.sort_values(by =['', 'population'], ascending = [True, False], inplace=True)
#       4
#       5 data_frames[['ID', 'state_name', 'population']].head(40)
#
# d:\Projects\Pycharm Source\nga_venv\lib\site-packages\pandas\util\_decorators.py in ?(*args, **kwargs)
#     327                     msg.format(arguments=_format_argument_list(allow_args)),
#     328                     FutureWarning,
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#
# ...

# %%
# Get the largest number of population
data_frames['population'].nlargest(10)
# Out:
# 0    18972871
# 1    12121244
# 2     8595181
# 3     5711945
# 4     5668165
# 5     5650910
# 6     5512873
# 7     5046555
# 8     4810669
# 9     4208580
# Name: population, dtype: int64
